# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %%
epochs = 10
train_batch = 64
test_batch = 128
learning_rate = 0.1
momentum = 0.5
log_interval = 10

random_seed = 0.1
torch.backends.cudnn.enabled = False
torch.manual_seed(random_seed)

# %%
data_dir = "./data_pytorch/"

# %%
set_transform = transforms.Compose([transforms.ToTensor()])
train_set = torchvision.datasets.MNIST(root=data_dir,train=True,download=True,transform=set_transform)
test_set = torchvision.datasets.MNIST(root=data_dir,train=False,download=True,transform=set_transform)
# Out:
# 0it [00:00, ?it/s]
# ...
#   0%|          | 0/9912422 [00:02<?, ?it/s]
#
#   0%|          | 8192/9912422 [00:05<57:43, 2859.29it/s]
#
#   0%|          | 16384/9912422 [00:07<52:44, 3127.28it/s]
#
#   0%|          | 24576/9912422 [00:09<49:14, 3346.80it/s]
#
#   0%|          | 32768/9912422 [00:10<39:22, 4181.65it/s]
#
#   0%|          | 40960/9912422 [00:11<32:28, 5066.99it/s]
#
#   0%|          | 49152/9912422 [00:11<25:10, 6527.85it/s]
#
#   1%|          | 57344/9912422 [00:12<19:49, 8288.50it/s]
#
#   1%|          | 65536/9912422 [00:12<16:34, 9900.25it/s]
#
#   1%|          | 81920/9912422 [00:13<12:48, 12785.06it/s]
#
#   1%|          | 98304/9912422 [00:13<10:03, 16266.03it/s]
#
#   1%|▏         | 131072/9912422 [00:14<08:17, 19641.72it/s]
#
#   2%|▏         | 163840/9912422 [00:14<06:23, 25395.35it/s]
#
#   2%|▏         | 180224/9912422 [00:15<06:54, 23485.85it/s]
#
#   2%|▏         | 204800/9912422 [00:16<06:01, 26822.68it/s]
#
# ...

# %%
print(train_set)
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data_pytorch/
#     Split: Train

# %%
print(list(train_set.data.size()))
print(train_set.train_data.float().mean()/255)
print(train_set.train_data.float().std()/255)
# Out:
# [60000, 28, 28]
# tensor(0.1307)
# tensor(0.3081)

# %%
train_loader = torch.utils.data.DataLoader(train_set.data.torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,)),batch_size=train_batch, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-aa98ed06be35> in <module>
# ----> 1 train_loader = torch.utils.data.DataLoader(train_set.data.torchvision.transforms.Normalize(
#       2                                  (0.1307,), (0.3081,)),
#       3   batch_size=train_batch, shuffle=True)
#
# AttributeError: 'Tensor' object has no attribute 'torchvision'
